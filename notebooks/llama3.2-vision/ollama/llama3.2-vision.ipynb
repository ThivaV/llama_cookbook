# %% [markdown]
# # llama3.2-vision

# %% [markdown]
# ## With ollama 11B

# %%
import ollama

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['../../../data/master_data/v1/istockphoto-1.jpg']
    }]
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = ollama.chat(
#       2     model='llama3.2-vision',
#       3     messages=[{
#       4         'role': 'user',
#       5         'content': 'What is in this image?',
#       6         'images': ['../../../data/master_data/v1/istockphoto-1.jpg']
#       7     }]
#       8 )
#      10 print(response)
#
# File /mnt/d/vault/devhub/llm_cookbooks/llama_cookbook/.venv/lib/python3.9/site-packages/ollama/_client.py:236, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     233   if images := message.get('images'):
#     234     message['images'] = [_encode_image(image) for image in images]
# --> 236 return self._request_stream(
#     237   'POST',
#     238   '/api/chat',
#     239   json={
#     240     'model': model,
#     241     'messages': messages,
# ...
